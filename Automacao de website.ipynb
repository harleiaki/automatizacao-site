# %% [markdown]
# # Automação Web e Busca de Informações com Python
#
# #### Desafio:
#
# Aqui estou usando automatização para ganhar pontos no Rewards
#
# Para isso, vamos criar uma automação web:
#
# - Usaremos o selenium
# - Importante: baixar o webdriver

# %%
import pyautogui
from time import sleep
from selenium import webdriver

# %%
#coordenadas de click
# pip install MouseInfo

# %%
# python
# from mouseinfo import mouseInfo
# mouseInfo()

# %%
# # # firefox -> geckodriver
# # # chrome -> chromedriver
# # # Aqui estou usando BlueSky Browser que é mais rápido 

# # # Passo a Passo
# # # Passo 1: Abrir o navegador
# # from selenium import webdriver
# pyautogui.click(704,1052,duration=1)
# pyautogui.click(684,657,duration=1)
# pyautogui.click(612,315,duration=1)
# pyautogui.write('q')
# pyautogui.click(1164,313,duration=1)
# pyautogui.click(427,160,duration=1.5)
# pyautogui.write('E')
# pyautogui.click(386,153,duration=0.3)

# %%
pyautogui.click(704,1052,duration=1)
#         # pyautogui.click(636,70,duration=2)
#         # pyautogui.write('z')
#         # pyautogui.press('enter')
pyautogui.click(262,152,duration=2)
pyautogui.write('a')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('i')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('d')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('o')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('d')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('s')
pyautogui.press('enter')
pyautogui.click(262,152,duration=2)
pyautogui.write('a')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('t')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('i')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('e')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('c')
pyautogui.press('enter')
pyautogui.click(262,152,duration=2)
pyautogui.write('e')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('r')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('o')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('p')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('m')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('e')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('t')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('a')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('m')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('i')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('l')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('c')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('a')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('i')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('d')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('o')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('d')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('e')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('s')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('a')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('r')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('f')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('e')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('j')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('o')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('h')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('a')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('t')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('l')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('a')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('m')
pyautogui.press('enter')
pyautogui.click(262,152,duration=1)
pyautogui.write('e')
pyautogui.press('enter')
