# %% [markdown]
# # Automação Web e Busca de Informações com Python
#
# #### Desafio:
#
# Aqui estou usando automatização para ganhar pontos no Rewards
#
# Para isso, vamos criar uma automação web:
#
# - Usaremos o selenium
# - Importante: baixar o webdriver

# %%
# !pip install selenium
import pyautogui
from time import sleep

# %%
#coordenadas de click
# pip install MouseInfo

# %%
# firefox -> geckodriver
# chrome -> chromedriver
# Aqui estou usando BlueSky Browser que é mais rápido 

# Passo a Passo
# Passo 1: Abrir o navegador
from selenium import webdriver
pyautogui.click(704,1052,duration=1.5)
pyautogui.click(735,313,duration=1.5)
pyautogui.write('q')
pyautogui.click(1183,310,duration=1.5)
pyautogui.click(555,141,duration=1.5)
pyautogui.write('E')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('R')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('T')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('Y')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('H')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('J')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('F')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('G')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('a')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('d')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('E')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('R')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('T')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('Y')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('H')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('J')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('F')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('G')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('a')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('d')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('E')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('R')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('T')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('Y')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('H')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('J')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('F')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('G')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('a')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('d')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('E')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('R')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('T')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('Y')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('H')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('J')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('F')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('G')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('a')
pyautogui.click(231,158,duration=0.3)
pyautogui.click(555,141,duration=0.3)
pyautogui.write('d')
pyautogui.click(231,158,duration=0.3)
